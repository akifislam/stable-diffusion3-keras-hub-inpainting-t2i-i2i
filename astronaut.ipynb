# %%
# Cell 1 — Install & import dependencies
# !pip install -U keras
# !pip install -U git+https://github.com/keras-team/keras-hub.git
# !pip install tensorflow[and-cuda]  # gives correct CUDA libs automatically

import os
os.environ["KERAS_BACKEND"] = "tensorflow"

import time
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

import keras
import keras_hub
# Out:
# Requirement already satisfied: keras in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (3.12.0)
# Requirement already satisfied: absl-py in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from keras) (2.3.1)
# Requirement already satisfied: numpy in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from keras) (2.1.3)
# Requirement already satisfied: rich in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from keras) (14.2.0)
# Requirement already satisfied: namex in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from keras) (0.1.0)
# Requirement already satisfied: h5py in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from keras) (3.15.1)
# Requirement already satisfied: optree in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from keras) (0.17.0)
# Requirement already satisfied: ml-dtypes in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from keras) (0.5.3)
# Requirement already satisfied: packaging in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from keras) (25.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from optree->keras) (4.15.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from rich->keras) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from rich->keras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Collecting git+https://github.com/keras-team/keras-hub.git
#   Cloning https://github.com/keras-team/keras-hub.git to /tmp/pip-req-build-pvwvpph6
#   Running command git clone --filter=blob:none --quiet https://github.com/keras-team/keras-hub.git /tmp/pip-req-build-pvwvpph6
#   Resolved https://github.com/keras-team/keras-hub.git to commit c7bd26ddbbaf79e710ad35951fa62ccf1255784d
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: keras>=3.8 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from keras-hub==0.24.0.dev0) (3.12.0)
# Requirement already satisfied: absl-py in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from keras-hub==0.24.0.dev0) (2.3.1)
# Requirement already satisfied: numpy in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from keras-hub==0.24.0.dev0) (2.1.3)
# Requirement already satisfied: packaging in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from keras-hub==0.24.0.dev0) (25.0)
# Requirement already satisfied: regex in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from keras-hub==0.24.0.dev0) (2025.11.3)
# Requirement already satisfied: rich in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from keras-hub==0.24.0.dev0) (14.2.0)
# Requirement already satisfied: kagglehub in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from keras-hub==0.24.0.dev0) (0.3.13)
# Requirement already satisfied: tensorflow-text in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from keras-hub==0.24.0.dev0) (2.19.0)
# Requirement already satisfied: namex in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from keras>=3.8->keras-hub==0.24.0.dev0) (0.1.0)
# Requirement already satisfied: h5py in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from keras>=3.8->keras-hub==0.24.0.dev0) (3.15.1)
# Requirement already satisfied: optree in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from keras>=3.8->keras-hub==0.24.0.dev0) (0.17.0)
# Requirement already satisfied: ml-dtypes in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from keras>=3.8->keras-hub==0.24.0.dev0) (0.5.3)
# Requirement already satisfied: pyyaml in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from kagglehub->keras-hub==0.24.0.dev0) (6.0.3)
# Requirement already satisfied: requests in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from kagglehub->keras-hub==0.24.0.dev0) (2.32.5)
# Requirement already satisfied: tqdm in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from kagglehub->keras-hub==0.24.0.dev0) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from optree->keras>=3.8->keras-hub==0.24.0.dev0) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from requests->kagglehub->keras-hub==0.24.0.dev0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from requests->kagglehub->keras-hub==0.24.0.dev0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from requests->kagglehub->keras-hub==0.24.0.dev0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from requests->kagglehub->keras-hub==0.24.0.dev0) (2025.10.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from rich->keras-hub==0.24.0.dev0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from rich->keras-hub==0.24.0.dev0) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras-hub==0.24.0.dev0) (0.1.2)
# Requirement already satisfied: tensorflow<2.20,>=2.19.0 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorflow-text->keras-hub==0.24.0.dev0) (2.19.1)
# Requirement already satisfied: astunparse>=1.6.0 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorflow<2.20,>=2.19.0->tensorflow-text->keras-hub==0.24.0.dev0) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorflow<2.20,>=2.19.0->tensorflow-text->keras-hub==0.24.0.dev0) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorflow<2.20,>=2.19.0->tensorflow-text->keras-hub==0.24.0.dev0) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorflow<2.20,>=2.19.0->tensorflow-text->keras-hub==0.24.0.dev0) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorflow<2.20,>=2.19.0->tensorflow-text->keras-hub==0.24.0.dev0) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorflow<2.20,>=2.19.0->tensorflow-text->keras-hub==0.24.0.dev0) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorflow<2.20,>=2.19.0->tensorflow-text->keras-hub==0.24.0.dev0) (3.20.3)
# Requirement already satisfied: setuptools in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorflow<2.20,>=2.19.0->tensorflow-text->keras-hub==0.24.0.dev0) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorflow<2.20,>=2.19.0->tensorflow-text->keras-hub==0.24.0.dev0) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorflow<2.20,>=2.19.0->tensorflow-text->keras-hub==0.24.0.dev0) (3.2.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorflow<2.20,>=2.19.0->tensorflow-text->keras-hub==0.24.0.dev0) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorflow<2.20,>=2.19.0->tensorflow-text->keras-hub==0.24.0.dev0) (1.76.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorflow<2.20,>=2.19.0->tensorflow-text->keras-hub==0.24.0.dev0) (2.19.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorflow<2.20,>=2.19.0->tensorflow-text->keras-hub==0.24.0.dev0) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19.0->tensorflow-text->keras-hub==0.24.0.dev0) (3.10)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19.0->tensorflow-text->keras-hub==0.24.0.dev0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19.0->tensorflow-text->keras-hub==0.24.0.dev0) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow<2.20,>=2.19.0->tensorflow-text->keras-hub==0.24.0.dev0) (0.45.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow<2.20,>=2.19.0->tensorflow-text->keras-hub==0.24.0.dev0) (3.0.3)
# Requirement already satisfied: tensorflow[and-cuda] in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (2.19.1)
# Requirement already satisfied: absl-py>=1.0.0 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorflow[and-cuda]) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorflow[and-cuda]) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorflow[and-cuda]) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorflow[and-cuda]) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorflow[and-cuda]) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorflow[and-cuda]) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorflow[and-cuda]) (3.4.0)
# Requirement already satisfied: packaging in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorflow[and-cuda]) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorflow[and-cuda]) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorflow[and-cuda]) (2.32.5)
# Requirement already satisfied: setuptools in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorflow[and-cuda]) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorflow[and-cuda]) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorflow[and-cuda]) (3.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorflow[and-cuda]) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorflow[and-cuda]) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorflow[and-cuda]) (1.76.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorflow[and-cuda]) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorflow[and-cuda]) (3.12.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorflow[and-cuda]) (2.1.3)
# Requirement already satisfied: h5py>=3.11.0 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorflow[and-cuda]) (3.15.1)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorflow[and-cuda]) (0.5.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorflow[and-cuda]) (0.37.1)
# Requirement already satisfied: nvidia-cublas-cu12==12.5.3.2 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorflow[and-cuda]) (12.5.3.2)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.5.82 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorflow[and-cuda]) (12.5.82)
# Requirement already satisfied: nvidia-cuda-nvcc-cu12==12.5.82 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorflow[and-cuda]) (12.5.82)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.5.82 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorflow[and-cuda]) (12.5.82)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.5.82 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorflow[and-cuda]) (12.5.82)
# Requirement already satisfied: nvidia-cudnn-cu12==9.3.0.75 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorflow[and-cuda]) (9.3.0.75)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.3.61 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorflow[and-cuda]) (11.2.3.61)
# Requirement already satisfied: nvidia-curand-cu12==10.3.6.82 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorflow[and-cuda]) (10.3.6.82)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.3.83 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorflow[and-cuda]) (11.6.3.83)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.1.3 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorflow[and-cuda]) (12.5.1.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.23.4 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorflow[and-cuda]) (2.23.4)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.5.82 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorflow[and-cuda]) (12.5.82)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow[and-cuda]) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow[and-cuda]) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow[and-cuda]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow[and-cuda]) (2025.10.5)
# Requirement already satisfied: markdown>=2.6.8 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorboard~=2.19.0->tensorflow[and-cuda]) (3.10)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorboard~=2.19.0->tensorflow[and-cuda]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from tensorboard~=2.19.0->tensorflow[and-cuda]) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow[and-cuda]) (0.45.1)
# Requirement already satisfied: rich in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from keras>=3.5.0->tensorflow[and-cuda]) (14.2.0)
# Requirement already satisfied: namex in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from keras>=3.5.0->tensorflow[and-cuda]) (0.1.0)
# Requirement already satisfied: optree in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from keras>=3.5.0->tensorflow[and-cuda]) (0.17.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow[and-cuda]) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from rich->keras>=3.5.0->tensorflow[and-cuda]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from rich->keras>=3.5.0->tensorflow[and-cuda]) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /home/akif/.conda/envs/vision/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow[and-cuda]) (0.1.2)
# 2025-11-14 14:59:13.557753: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-14 14:59:13.566592: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763110753.575724 2987022 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763110753.578457 2987022 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763110753.586985 2987022 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1763110753.586992 2987022 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1763110753.586993 2987022 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1763110753.586994 2987022 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-11-14 14:59:13.589775: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Cell 2 — Display helper (official version)

def display_generated_images(images):
    """Helper function to display the images from the inputs.
    This function accepts:
    - 3D numpy array (H, W, 3)
    - 4D numpy array (N, H, W, 3): concatenated horizontally
    - List of 3D numpy arrays: concatenated horizontally
    """
    display_image = None

    if isinstance(images, np.ndarray):
        if images.ndim == 3:
            display_image = Image.fromarray(images)
        elif images.ndim == 4:
            concated_images = np.concatenate(list(images), axis=1)
            display_image = Image.fromarray(concated_images)

    elif isinstance(images, list):
        concated_images = np.concatenate(images, axis=1)
        display_image = Image.fromarray(concated_images)

    if display_image is None:
        raise ValueError("Unsupported input format.")

    plt.figure(figsize=(10, 10))
    plt.axis("off")
    plt.imshow(display_image)
    plt.show()
    plt.close()

# %%
# Cell 3 — Load backbone, preprocessor, and inpaint model
backbone = keras_hub.models.StableDiffusion3Backbone.from_preset(
    "stable_diffusion_3_medium",
    image_shape=(512,512,3),
    dtype="float16"
)
preprocessor = keras_hub.models.StableDiffusion3TextToImagePreprocessor.from_preset(
    "stable_diffusion_3_medium"
)
inpaint = keras_hub.models.StableDiffusion3Inpaint(backbone, preprocessor)
# Out:
# I0000 00:00:1763110754.993148 2987022 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 20698 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9
# 2025-11-14 14:59:15.543676: E tensorflow/core/util/util.cc:131] oneDNN supports DT_HALF only on platforms with AVX-512. Falling back to the default Eigen-based implementation if present.

# %%
# Cell 4 — Load & preprocess the reference image + mask
# Replace 'input_image.png' and 'input_mask.png' with your file paths
img = Image.open("input_image.png").convert("RGB")
img = img.resize((512,512))
img_arr = np.array(img).astype("float32")
# rescale to [-1,1]
img_arr = (img_arr / 127.5) - 1.0

mask = Image.open("input_mask.png").convert("L")  # a single‐channel mask
mask = mask.resize((512,512))
mask_arr = np.array(mask)
# set mask to boolean: True where you want to edit (white), False where you keep original (black)
mask_bool = mask_arr > 127  # threshold

# %%
# Cell 5 — Improved inpaint generation (correct scaling)

prompts = [
    "A lone astronaut standing on a serene garden path covered in soft white rose petals, surrounded by blooming ivory cherry blossoms gently arching overhead. Warm sunlight filters through the delicate blossoms, creating a magical, ethereal atmosphere. Hyper-detailed petals floating in the breeze, soft shadows, crisp reflections on the astronaut’s visor, cinematic depth of field, ultra-realistic textures, peaceful and enchanting mood, masterpiece photography"
]

guidance_scales = [5.0, 7.5, 10.0]
strength_values  = [0.4, 0.6, 0.8]
num_steps = 2000

results = []

for prompt in prompts:
    for gs in guidance_scales:
        for st in strength_values:

            print(f"Generating with guidance={gs}, strength={st}")

            out = inpaint.generate(
                {
                    "images": img_arr,
                    "masks": mask_bool,
                    "prompts": prompt,
                },
                num_steps=num_steps,
                guidance_scale=gs,
                strength=st,
            )

            # ⚠️ NO extra rescaling here.
            # Ensure it's uint8 and drop any batch dim if present.
            out = np.array(out)
            if out.ndim == 4:
                out = out[0]  # (1, H, W, 3) -> (H, W, 3)
            out_uint8 = out.astype("uint8")

            results.append(out_uint8)

# Display all generated images
display_generated_images(np.stack(results, axis=0))
# Out:
# Generating with guidance=5.0, strength=0.4
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1763110768.089240 2987022 service.cc:152] XLA service 0x47b566f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1763110768.089260 2987022 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2025-11-14 14:59:28.776450: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1763110771.182498 2987022 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 2025-11-14 14:59:34.450399: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2066', 32 bytes spill stores, 32 bytes spill loads
#
# 2025-11-14 14:59:34.544135: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2066', 32 bytes spill stores, 32 bytes spill loads
#
# 2025-11-14 14:59:34.562695: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2067', 92 bytes spill stores, 92 bytes spill loads
#
# 2025-11-14 14:59:34.576640: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2066', 52 bytes spill stores, 52 bytes spill loads
#
# 2025-11-14 14:59:34.722365: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2066', 104 bytes spill stores, 104 bytes spill loads
#
# 2025-11-14 14:59:34.790545: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2066', 28 bytes spill stores, 28 bytes spill loads
#
# 2025-11-14 14:59:34.798011: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2066', 112 bytes spill stores, 112 bytes spill loads
#
# 2025-11-14 14:59:34.833399: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2067', 296 bytes spill stores, 260 bytes spill loads
#
# 2025-11-14 14:59:35.109929: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2066', 84 bytes spill stores, 84 bytes spill loads
#
# 2025-11-14 14:59:35.489903: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1189', 4 bytes spill stores, 4 bytes spill loads
#
# 2025-11-14 14:59:35.753844: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1189', 148 bytes spill stores, 148 bytes spill loads
#
# 2025-11-14 14:59:35.994480: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1979_0', 196 bytes spill stores, 388 bytes spill loads
#
# 2025-11-14 14:59:36.041661: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2067', 1204 bytes spill stores, 956 bytes spill loads
#
# 2025-11-14 14:59:36.055234: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1979_0', 52 bytes spill stores, 52 bytes spill loads
#
# 2025-11-14 14:59:36.116159: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2043_0', 152 bytes spill stores, 164 bytes spill loads
#
# 2025-11-14 14:59:36.532396: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2043_0', 60 bytes spill stores, 60 bytes spill loads
#
# I0000 00:00:1763110786.940049 2987022 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Generating with guidance=5.0, strength=0.6
# Generating with guidance=5.0, strength=0.8
# Generating with guidance=7.5, strength=0.4
# Generating with guidance=7.5, strength=0.6
# Generating with guidance=7.5, strength=0.8
# Generating with guidance=10.0, strength=0.4
# Generating with guidance=10.0, strength=0.6
# Generating with guidance=10.0, strength=0.8

# %%
# Cell 6 — Display original image and mask only

orig_uint8 = ((img_arr + 1.0) * 127.5).clip(0,255).astype(np.uint8)
mask_vis   = np.stack([mask_bool.astype(np.uint8)*255]*3, axis=-1)

display_generated_images([orig_uint8, mask_vis])

# %%
# Cell 6 — Display original image, mask, first generated result

orig_uint8 = ((img_arr + 1.0) * 127.5).clip(0,255).astype(np.uint8)
mask_vis   = np.stack([mask_bool.astype(np.uint8)*255]*3, axis=-1)

first_output = results[0]   # pick first of 9 images

display_generated_images([orig_uint8, mask_vis, first_output])

# %%
# Cell 6 — Display all generated results (grid)

display_generated_images(results)

# %%
# Cell 7 — Save the first generated result

out_img = results[-2]     # pick first generated image
Image.fromarray(out_img).save("inpainted_output_1.png")

print("Saved: inpainted_output_1.png")
# Out:
# Saved: inpainted_output_1.png
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
